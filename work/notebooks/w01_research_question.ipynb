# %% [markdown]
# # ML-02 — Research Question and Provisional Lane
#
# [![Open In Colab](https://colab.research.google.com/assets/colab-badge.svg)](https://colab.research.google.com/github/Maro200611/flyrank-ml-internship/blob/main/work/notebooks/w01_research_question.ipynb?flush_cache=true)
#
# This skeleton is yours to fill. Work the sections **in order** — each one has a one-line hint. Simple words, honest numbers.
#
# > Working with an AI assistant? Tell it to read `skills/README.md` first and load the one skill this assignment names on its card.

# %% [markdown]
# ## 1. My lane (or freestyle) and why
#
# *Name your lane — or say 'freestyle' and describe your own question. One short paragraph: why this one?*

# %% [markdown]
# ## My lane
#
# I choose **Ranking Signal Analysis** because I want to understand what search signals are related to better search performance. I think this lane is good for me because I want to learn more about data analysis and machine learning using real search data. It will also help me improve my skills by working with a real dataset.

# %%
# This cell is for CODE (numbers, a query, a check).
# Write your text answer in the cell ABOVE this one — typing sentences here breaks Run All.

# %% [markdown]
# ## 2. The question: decision, action, cost of a wrong call
#
# *What decision does your work improve? Who acts on it? What does a wrong recommendation cost?*

# %% [markdown]
# ## Research Question
#
# My project helps content teams decide which pages should be improved first based on search signals. The main decision is choosing where to spend time for content improvement. A wrong recommendation can waste time on pages that do not need updates and miss pages that have more opportunity to grow.

# %%
# This cell is for CODE (numbers, a query, a check).
# Write your text answer in the cell ABOVE this one — typing sentences here breaks Run All.

# %% [markdown]
# ## 3. Quick look at the data (2-3 real numbers)
#
# *Load the starter CSV below and show 2-3 real numbers that make your lane look worth the next 7 weeks.*

# %% [markdown]
# ## Quick look at the data
#
# The starter dataset contains 30,000 rows and 44 columns. The average value of search_volume is 152.82. These numbers show that the dataset has enough information to study ranking signals and build useful recommendations.

# %%
# This cell is for CODE (numbers, a query, a check).
# Write your text answer in the cell ABOVE this one — typing sentences here breaks Run All.

import pandas as pd

df = pd.read_csv("data/raw/content_refresh_anonymized.csv")

rows = len(df)
cols = len(df.columns)

print(f"Number of rows: {rows}")
print(f"Number of columns: {cols}")

print("\nFirst 5 columns:")
print(list(df.columns[:5]))

numeric_cols = df.select_dtypes(include=['number']).columns
if len(numeric_cols) > 0:
    target_col = numeric_cols[0]
    avg_val = df[target_col].mean()
    print(f"\nAverage value of '{target_col}': {avg_val:.2f}")
else:
    print("\nNo numeric columns found.")
# Out:
# Number of rows: 30000
# Number of columns: 44
#
# First 5 columns:
# ['content_id', 'client_id', 'search_volume', 'competition', 'competition_level']
#
# Average value of 'search_volume': 158.88

# %% [markdown]
# ## 4. Careful words: what I can and can't claim
#
# *Write what your work will be able to say (observed, directional, decision-support) — and what it never will (causal proof, 'predicting Google').*

# %%
# This cell is for CODE (numbers, a query, a check).
# Write your text answer in the cell ABOVE this one — typing sentences here breaks Run All.

# %% [markdown]
# ## Self-check
#
# Before you submit, confirm each line honestly:
#
# - [ ] Every section above is filled — markdown thinking AND the code that backs it
# - [ ] The notebook runs top to bottom with no errors (Runtime → Run all)
# - [ ] No client names, URLs, or private queries anywhere
# - [ ] My claims use careful words: observed, measured, directional, decision-support
# - [ ] Committed to my repo under `work/notebooks/` — then submit your repo URL on the card. Done.
